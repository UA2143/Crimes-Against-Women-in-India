# %% [markdown]
# # Crime Against Women

# %% [markdown]
# This data is collated from https://data.gov.in. It has state-wise data on the various crimes committed against women between 2001 to 2021. Some crimes that are included are Rape, Kidnapping and Abduction, Dowry Deaths etc.

# %% [markdown]
# NOTE:
# Andhra Pradesh and Telengana split to form new
#
# *   Andhra Pradesh and Telengana split to form separate states in 2014. Data of Telengana is separate from 2014-2021.
# *   Even though Jammu Kashmir and Ladakh split to form different union territories, their data is combined from 2019-2021

# %% [markdown]
# ###Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Reading Dataset

# %%
df = pd.read_csv("CrimesOnWomenData.csv")

df.iloc[:,1:].head()
# Out:
#                State  Year  Rape  Kidnapping & Assault  Dowry Deaths  \
# 0     ANDHRA PRADESH  2001   871                   765           420
# 1  ARUNACHAL PRADESH  2001    33                    55             0
# 2              ASSAM  2001   817                  1070            59
# 3              BIHAR  2001   888                   518           859
# 4       CHHATTISGARH  2001   959                   171            70
#
#    Assault against Women  Assault of Modesty  Domestic Violece  \
# 0                   3544                2271              5791
# 1                     78                   3                11
# 2                    850                   4              1248
# 3                    562                  21              1558
# 4                   1763                 161               840
#
#    Human trafficking
# 0                  7
# 1                  0
# 2                  0
# 3                 83
# 4                  0

# %% [markdown]
# ###Cleaning Data

# %%
df['State'] = df['State'].str.title()
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'A & N Islands', 'Chandigarh', 'D & N Haveli',
#        'Daman & Diu', 'A', 'Puducherry', 'Lakshadweep', 'Telangana',
#        'D&N Haveli', 'Delhi Ut'], dtype=object)

# %%
replacements = {'D & N Haveli': 'D & D', 'D&N Haveli': 'D & D', 'Daman & Diu': 'D & D', 'A':'Lakshadweep'}
df['State'] = df['State'].replace(replacements)

# %%
df['State'].unique()
# len(df['State'].unique())
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'A & N Islands', 'Chandigarh', 'D & D',
#        'Lakshadweep', 'Puducherry', 'Telangana', 'Delhi Ut'], dtype=object)

# %% [markdown]
# ### Analysing Data

# %%
df.shape
# Out:
# (736, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             736 non-null    int64
#  1   State                  736 non-null    object
#  2   Year                   736 non-null    int64
#  3   Rape                   736 non-null    int64
#  4   Kidnapping & Assault   736 non-null    int64
#  5   Dowry Deaths           736 non-null    int64
#  6   Assault against Women  736 non-null    int64
#  7   Assault of Modesty     736 non-null    int64
#  8   Domestic Violece       736 non-null    int64
#  9   Human trafficking      736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Year         Rape  Kidnapping & Assault  \
# count  736.000000   736.000000   736.000000            736.000000
# mean   367.500000  2011.149457   727.855978           1134.542120
# std    212.609188     6.053453   977.024945           1993.536828
# min      0.000000  2001.000000     0.000000              0.000000
# 25%    183.750000  2006.000000    35.000000             24.750000
# 50%    367.500000  2011.000000   348.500000            290.000000
# 75%    551.250000  2016.000000  1069.000000           1216.000000
# max    735.000000  2021.000000  6337.000000          15381.000000
#
#        Dowry Deaths  Assault against Women  Assault of Modesty  \
# count    736.000000             736.000000          736.000000
# mean     215.692935            1579.115489          332.722826
# std      424.927334            2463.962518          806.024551
# min        0.000000               0.000000            0.000000
# 25%        1.000000              34.000000            3.000000
# 50%       29.000000             387.500000           31.000000
# 75%      259.000000            2122.250000          277.500000
# max     2524.000000           14853.000000         9422.000000
#
#        Domestic Violece  Human trafficking
# count        736.000000         736.000000
# mean        2595.078804          28.744565
# std         4042.004953          79.999660
# min            0.000000           0.000000
# 25%           13.000000           0.000000
# 50%          678.500000           0.000000
# 75%         3545.000000          15.000000
# max        23278.000000         549.000000

# %% [markdown]
# ### Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# State                    0
# Year                     0
# Rape                     0
# Kidnapping & Assault     0
# Dowry Deaths             0
# Assault against Women    0
# Assault of Modesty       0
# Domestic Violece         0
# Human trafficking        0
# dtype: int64

# %% [markdown]
# ## Crimes over the years in India

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'State',
#  'Year',
#  'Rape',
#  'Kidnapping & Assault',
#  'Dowry Deaths',
#  'Assault against Women',
#  'Assault of Modesty',
#  'Domestic Violece',
#  'Human trafficking']

# %%
def crimes_by_different_order(dataframe,column_name):
    "This function returns a dataframe with total number of particular crimes grouping by certain column"
    for column in list(df.columns)[3:]:
        dataframe[column]=df.groupby([column_name])[column].sum()
    return dataframe

total_crimes_in_years_df=pd.DataFrame()
total_crimes_in_years_df=crimes_by_different_order(total_crimes_in_years_df,"Year")
total_crimes_in_years_df.reset_index(inplace=True)
total_crimes_in_years_df
# Out:
#     Year   Rape  Kidnapping & Assault  Dowry Deaths  Assault against Women  \
# 0   2001  15694                 13681          6738                  33622
# 1   2002  15970                 13613          6687                  33497
# 2   2003  15357                 12499          6078                  32450
# 3   2004  17682                 14697          6900                  33966
# 4   2005  17701                 14644          6673                  33413
# 5   2006  18725                 16348          7481                  35899
# 6   2007  20139                 19249          7955                  37866
# 7   2008  21001                 21803          8043                  39802
# 8   2009  20928                 24086          8242                  38159
# 9   2010  21665                 28055          8248                  40012
# 10  2011  24206                 35565          8618                      0
# 11  2012  24923                 38262          8233                  45344
# 12  2013  33707                 51881          8083                  70739
# 13  2014  36735                 57311         10050                  82235
# 14  2015  34651                 59277          7634                  82422
# 15  2016  38947                 64519          7621                  84746
# 16  2017  32559                 66333          7466                  86001
# 17  2018  33356                 72751          7166                  89097
# 18  2019  32033                 72780          7115                  88367
# 19  2020  28046                 62300          6966                  85392
# 20  2021  31677                 75369          6753                  89200
#
#     Assault of Modesty  Domestic Violece  Human trafficking
# 0                 9656             49032                114
# 1                10027             49102                 76
# 2                12220             49492                 46
# 3                 9871             56867                 89
# 4                 9759             56995                148
# 5                 9822             61400                 67
# 6                10783             74143                 61
# 7                12084             79957                 67
# 8                10891             88263                 48
# 9                 9881             92637                 36
# 10                8570             99135               2435
# 11                9173            106527               2563
# 12               12589            118866               2579
# 13               21938            122877               2070
# 14               24041            113403               2424
# 15               27344            110378               2214
# 16                7451            104551               1536
# 17                6992            103272               1459
# 18                6939            125298               1185
# 19                7065            111549                868
# 20                7788            136234               1071

# %%
total_crimes_in_years_df['Total Number of Cases']=total_crimes_in_years_df.sum(axis=1)
total_crimes_in_years_df["Total Number of Cases"].sum()
# Out:
# 4909953

# %% [markdown]
# *More than 49 lakh cases registered between 2001 and 2021*

# %% [markdown]
# Function to plot graphs

# %%
#using plotly.graph_objects

def plot_figure(title: str, crime: str,ylabel: str,color: str="red"):
    """This function generate a bar graph using the total_crimes_in_years_df
    Parameters:
    title: insert title of bar graph,
    crime: insert column name according to dataframe,
    y_label: insert y label of bar graph,
    color: insert color choice according plotly.graph_options"""
    fig = go.Figure(data=[go.Bar(
            x=total_crimes_in_years_df["Year"], y=total_crimes_in_years_df[crime],
            text=total_crimes_in_years_df[crime],
        )])
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside',marker_color=color)
    fig.update_layout(title=title,
                       xaxis = dict(title='Years',
                                    tickmode = 'linear',
                                    tickangle=-30 ),
                   yaxis_title=ylabel,uniformtext_minsize=8, uniformtext_mode='show')

    fig.show()

# %%
# Rape cases in India in 2001-2021
plot_figure("Rape cases in India in 2001-2021","Rape","Cases of Rape in India", color='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51e9da9d-2032-40da-a4fd-0c8ce22b25e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51e9da9d-2032-40da-a4fd-0c8ce22b25e7")) {                    Plotly.newPlot(                        "51e9da9d-2032-40da-a4fd-0c8ce22b25e7",                        [{"text":[15694.0,15970.0,15357.0,17682.0,17701.0,18725.0,20139.0,21001.0,20928.0,21665.0,24206.0,24923.0,33707.0,36735.0,34651.0,38947.0,32559.0,33356.0,32033.0,28046.0,31677.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[15694,15970,15357,17682,17701,18725,20139,21001,20928,21665,24206,24923,33707,36735,34651,38947,32559,33356,32033,28046,31677],"type":"bar","marker":{"color":"blue"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil ...

# %% [markdown]
# **Analysis:**
#
# * **Increasing Trend:** There is a clear upward trend in the number of rape cases in India from 2001 to 2014. The number of cases generally increases each year, with a few minor fluctuations
# *   **Significant Growth:** The increase in rape cases is substantial, with the number of cases rising from around 16,000 in 2001 to over 39,000 in 2016.

# %%
# Kidnapping and Assault vs years
plot_figure("Kidnapping and Assault cases in India in 2001-2021","Kidnapping & Assault","Cases of Kidnapping and Assault in India", color='crimson')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02685c12-334a-4578-86db-746dba926cda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02685c12-334a-4578-86db-746dba926cda")) {                    Plotly.newPlot(                        "02685c12-334a-4578-86db-746dba926cda",                        [{"text":[13681.0,13613.0,12499.0,14697.0,14644.0,16348.0,19249.0,21803.0,24086.0,28055.0,35565.0,38262.0,51881.0,57311.0,59277.0,64519.0,66333.0,72751.0,72780.0,62300.0,75369.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[13681,13613,12499,14697,14644,16348,19249,21803,24086,28055,35565,38262,51881,57311,59277,64519,66333,72751,72780,62300,75369],"type":"bar","marker":{"color":"crimson"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{" ...

# %% [markdown]
# **Analysis:**
#
# *   **Steady Increase:**
# The graph reveals a consistent upward trend in the number of Kidnapping and Assault cases in India from 2001 to 2021.
# *   **Significant Growth:** The number of cases has nearly tripled during this period, indicating a serious concern.
# *   **Fluctuations:** While the overall trend is upward, there are some year-to-year fluctuations. This could be attributed to various factors like changes in reporting mechanisms, socio-economic conditions, and law enforcement efforts.

# %%
# Dowry Deaths
plot_figure("Dowry Death cases in India in 2001-2021","Dowry Deaths","Cases of Dowry Deaths in India", color='navy')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6bcb73ec-92af-4c76-8155-bb7e7df07c2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bcb73ec-92af-4c76-8155-bb7e7df07c2d")) {                    Plotly.newPlot(                        "6bcb73ec-92af-4c76-8155-bb7e7df07c2d",                        [{"text":[6738.0,6687.0,6078.0,6900.0,6673.0,7481.0,7955.0,8043.0,8242.0,8248.0,8618.0,8233.0,8083.0,10050.0,7634.0,7621.0,7466.0,7166.0,7115.0,6966.0,6753.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[6738,6687,6078,6900,6673,7481,7955,8043,8242,8248,8618,8233,8083,10050,7634,7621,7466,7166,7115,6966,6753],"type":"bar","marker":{"color":"navy"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %%
# Assault
plot_figure("Assault against women cases in India in 2001-2021","Assault against Women","Cases of Assault against women in India", color='rgb(13, 154, 218)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb62159b-972a-4a38-aed6-807e2e5b5b7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb62159b-972a-4a38-aed6-807e2e5b5b7d")) {                    Plotly.newPlot(                        "bb62159b-972a-4a38-aed6-807e2e5b5b7d",                        [{"text":[33622.0,33497.0,32450.0,33966.0,33413.0,35899.0,37866.0,39802.0,38159.0,40012.0,0.0,45344.0,70739.0,82235.0,82422.0,84746.0,86001.0,89097.0,88367.0,85392.0,89200.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[33622,33497,32450,33966,33413,35899,37866,39802,38159,40012,0,45344,70739,82235,82422,84746,86001,89097,88367,85392,89200],"type":"bar","marker":{"color":"rgb(13, 154, 218)"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern": ...

# %% [markdown]
# **Analysis**
# *  **Increasing Trend:** The graph reveals a clear upward trend in the number of Assault Against Women cases in India from 2001 to 2021.
# *  **Significant Growth:** The number of cases has increased significantly over the period, highlighting a serious issue.
# *  **Fluctuations:** While the overall trend is upward, there are some year-to-year fluctuations. This could be attributed to various factors like changes in reporting mechanisms, socio-economic conditions, and law enforcement efforts.
# *  **Data Gap:** The missing data for 2011 could potentially skew the overall trend. Further investigation is needed to understand the reasons for this data gap and its impact on the analysis.

# %%
# Assault of Modesty
plot_figure("Assault of Modesty cases in India in 2001-2021","Assault of Modesty","Cases of Assault of Modesty in India", color='rgb(123, 19, 60)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9948011d-17c8-4f3d-b506-263fd2b244b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9948011d-17c8-4f3d-b506-263fd2b244b4")) {                    Plotly.newPlot(                        "9948011d-17c8-4f3d-b506-263fd2b244b4",                        [{"text":[9656.0,10027.0,12220.0,9871.0,9759.0,9822.0,10783.0,12084.0,10891.0,9881.0,8570.0,9173.0,12589.0,21938.0,24041.0,27344.0,7451.0,6992.0,6939.0,7065.0,7788.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[9656,10027,12220,9871,9759,9822,10783,12084,10891,9881,8570,9173,12589,21938,24041,27344,7451,6992,6939,7065,7788],"type":"bar","marker":{"color":"rgb(123, 19, 60)"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"over ...

# %% [markdown]
# **Analysis**
# *  **Increasing Trend:** The graph shows a general upward trend in the number of Assault of Modesty cases in India from 2001 to 2021.
# *  **Significant Spike:** There's a notable spike in cases around 2016, followed by a slight decline in subsequent years.
# Fluctuations: While the overall trend is increasing, there are some year-to-year fluctuations. This could be attributed to various factors like changes in reporting mechanisms, socio-economic conditions, and law enforcement efforts.

# %%
# Domestic violence
plot_figure("Domestic Violence cases in India in 2001-2021","Domestic Violece","Cases of Domestic Violence in India", color='rgb(222, 148, 54)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="377eb258-38fe-446b-af47-f35135d2ead5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("377eb258-38fe-446b-af47-f35135d2ead5")) {                    Plotly.newPlot(                        "377eb258-38fe-446b-af47-f35135d2ead5",                        [{"text":[49032.0,49102.0,49492.0,56867.0,56995.0,61400.0,74143.0,79957.0,88263.0,92637.0,99135.0,106527.0,118866.0,122877.0,113403.0,110378.0,104551.0,103272.0,125298.0,111549.0,136234.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[49032,49102,49492,56867,56995,61400,74143,79957,88263,92637,99135,106527,118866,122877,113403,110378,104551,103272,125298,111549,136234],"type":"bar","marker":{"color":"rgb(222, 148, 54)"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5E ...

# %% [markdown]
# **Analysis**
# * **Increasing Trend:** The graph reveals a clear upward trend in the number of Domestic Violence cases in India from 2001 to 2021.
# Significant Growth: The number of cases has increased substantially over the period, highlighting a serious societal issue.
# * **Fluctuations:** While the overall trend is upward, there are some year-to-year fluctuations. This could be attributed to various factors like changes in reporting mechanisms, socio-economic conditions, and law enforcement efforts.

# %%
# Human Traficking
plot_figure("Human Trafficking cases in India in 2001-2021","Human trafficking","Cases of Human Trafficking in India", color='lightsalmon')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5b2de20f-48e5-4cc9-8868-b4158031dabf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b2de20f-48e5-4cc9-8868-b4158031dabf")) {                    Plotly.newPlot(                        "5b2de20f-48e5-4cc9-8868-b4158031dabf",                        [{"text":[114.0,76.0,46.0,89.0,148.0,67.0,61.0,67.0,48.0,36.0,2435.0,2563.0,2579.0,2070.0,2424.0,2214.0,1536.0,1459.0,1185.0,868.0,1071.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[114,76,46,89,148,67,61,67,48,36,2435,2563,2579,2070,2424,2214,1536,1459,1185,868,1071],"type":"bar","marker":{"color":"lightsalmon"},"textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[ ...

# %% [markdown]
# **Analysis**
#
# *  **Increasing Trend:** The graph reveals a clear upward trend in the number of Human Trafficking cases in India from 2001 to 2021.
# Significant Growth: The number of cases has increased substantially over the period, highlighting a serious societal issue.
# *  **Fluctuations:** While the overall trend is upward, there are some year-to-year fluctuations. This could be attributed to various factors like changes in reporting mechanisms, socio-economic conditions, and law enforcement efforts.

# %% [markdown]
# ##Year wise Analysis of Crimes Against Women in India

# %% [markdown]
# ###Year wise Crime Againt women in India

# %%
#

fig = go.Figure(data=[go.Scatter(
            x=total_crimes_in_years_df["Year"], y=total_crimes_in_years_df["Total Number of Cases"],
            text=total_crimes_in_years_df["Total Number of Cases"],
        )])
fig.update_layout(title="Year wise crime against women in India(including States & UT)",
                       xaxis = dict(title='Years',
                                    tickmode = 'linear',
                                    tickangle=-30 ),
                      #yaxis=dict(title=, tickmode = 'linear', tick0 = 0.0,dtick = 0.25)
                   yaxis_title="Cases",yaxis_tickformat = 's',uniformtext_minsize=8, uniformtext_mode='show')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="674480a5-9522-4bc4-8912-a650aa769bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("674480a5-9522-4bc4-8912-a650aa769bef")) {                    Plotly.newPlot(                        "674480a5-9522-4bc4-8912-a650aa769bef",                        [{"text":[130538.0,130974.0,130145.0,142076.0,141338.0,151748.0,172203.0,184765.0,192626.0,202544.0,180540.0,237037.0,300457.0,335230.0,325867.0,337785.0,307914.0,316111.0,335736.0,304206.0,350113.0],"x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[130538,130974,130145,142076,141338,151748,172203,184765,192626,202544,180540,237037,300457,335230,325867,337785,307914,316111,335736,304206,350113],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidi ...

# %% [markdown]
# ###Rate of Change of Different Crimes###

# %%
#Rate of change of different crimes over time

fig = go.Figure()
color=["blue","crimson","navy","rgb(13, 154, 218)",'rgb(123, 19, 60)', 'rgb(222, 148, 54)','lightsalmon']
dash=["solid","dash","dot","solid","dash","dot", "solid"]
j=0
for i in total_crimes_in_years_df.columns:
    if i=="Total Number of Cases":
        break
    if i == "Year":
        continue
    fig.add_trace(go.Scatter(x=total_crimes_in_years_df.Year, y=total_crimes_in_years_df[i], name=i,
                         line=dict(color=color[j % len(color)], width=4, dash=dash[j % len(dash)])))
    j=j+1
# Edit the layout
fig.update_layout(title='Rate of change of different crime over time',
                   xaxis_title='Years',
                   yaxis_title='Spread of Cases')

fig.show()
fig = go.Figure()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73345e5b-01af-4d76-b6e0-377621768db9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73345e5b-01af-4d76-b6e0-377621768db9")) {                    Plotly.newPlot(                        "73345e5b-01af-4d76-b6e0-377621768db9",                        [{"line":{"color":"blue","dash":"solid","width":4},"name":"Rape","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[15694,15970,15357,17682,17701,18725,20139,21001,20928,21665,24206,24923,33707,36735,34651,38947,32559,33356,32033,28046,31677],"type":"scatter"},{"line":{"color":"crimson","dash":"dash","width":4},"name":"Kidnapping & Assault","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[13681,13613,12499,14697,14644,16348,19249,21803,24086,28055,35565,38262,51881,57311,59277,64519,66333,72751,72780,62300,75369],"type":"scatter"},{"line":{"color":"navy","dash":"dot","width":4},"name":"Dowry Deaths","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[6738,6687,6078,6900,6673,7481,7955,8043,8242,8248,8618,8233,8083,10050,7634,7621,7466,7166,7115,6966,6753],"type":"scatter"},{"line":{"color":"rgb(13, 154, 218)","dash":"solid","width":4},"name":"Assault against Women","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[33622,33497,32450,33966,33413,35899,37866,39802,38159,40012,0,45344,70739,82235,82422,84746,86001,89097,88367,85392,89200],"type":"scatter"},{"line":{"color":"rgb(123, 19, 60)","dash":"dash","width":4},"name":"Assault of Modesty","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[9656,10027,12220,9871,9759,9822,10783,12084,10891,9881,8570,9173,12589,21938,24041,27344,7451,6992,6939,7065,7788],"type":"scatter"},{"line":{"color":"rgb(222, 148, 54)","dash":"dot","width":4},"name":"Domestic Violece","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[49032,49102,49492,56867,56995,61400,74143,79957,88263,92637,99135,106527,118866,122877,113403,110378,104551,103272,125298,111549,136234],"type":"scatter"},{"line":{"color":"lightsalmon","dash":"solid","width":4},"name":"Human trafficking","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[114,76,46,89,148,67,61,67,48,36,2435,2563,2579,2070,2424,2214,1536,1459,1185,868,1071],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %%
crimes_in_years_df=total_crimes_in_years_df.drop("Total Number of Cases", axis=1)
crimes_in_years_df.set_index("Year", inplace = True)

# %% [markdown]
# ### Highest and Lowest Reported Crimes

# %%
pd.DataFrame(crimes_in_years_df.sum(axis=0),columns=['Count']).sort_values(by='Count',ascending=False)
# Out:
#                          Count
# Domestic Violece       1909978
# Assault against Women  1162229
# Kidnapping & Assault    835023
# Rape                    535702
# Assault of Modesty      244884
# Dowry Deaths            158750
# Human trafficking        21156

# %%
fig = px.pie(pd.DataFrame(crimes_in_years_df.sum(axis=0),columns=['Count']), values='Count', names=pd.DataFrame(crimes_in_years_df.sum(axis=0)).index, title='Percentage of Each Crime between 2001 - 2021')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8144f6ac-59a1-401c-806b-9b13db4e2daf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8144f6ac-59a1-401c-806b-9b13db4e2daf")) {                    Plotly.newPlot(                        "8144f6ac-59a1-401c-806b-9b13db4e2daf",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Rape","Kidnapping & Assault","Dowry Deaths","Assault against Women","Assault of Modesty","Domestic Violece","Human trafficking"],"legendgroup":"","name":"","showlegend":true,"values":[535702,835023,158750,1162229,244884,1909978,21156],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar" ...

# %% [markdown]
# ## State/UT Analysis

# %% [markdown]
# ###Total Crimes Reported across all States in 2001-2021

# %%
state_ut_crimes_df=pd.DataFrame()
state_ut_crimes_df=crimes_by_different_order(state_ut_crimes_df,"State")
state_ut_crimes_df
# Out:
#                     Rape  Kidnapping & Assault  Dowry Deaths  \
# State
# A & N Islands        424                   363            13
# Andhra Pradesh     23424                 21707          8165
# Arunachal Pradesh   1153                  1272             4
# Assam              32190                 71462          2757
# Bihar              21006                 77687         24428
# Chandigarh           795                  1547            68
# Chhattisgarh       25178                 16536          1797
# D & D               2962                  8873           286
# Delhi Ut           13065                 31251          1106
# Goa                 1019                   720            23
# Gujarat             9940                 25733           652
# Haryana            17776                 29593          5144
# Himachal Pradesh    4474                  4043            76
# Jammu & Kashmir     7656                 17464           735
# Jharkhand          18054                 13604          6814
# Karnataka          12723                 15258          6028
# Kerala             24184                 14056          1525
# Lakshadweep           20                     1             0
# Madhya Pradesh     72808                 57485         13316
# Maharashtra        39252                 46522          5756
# Manipur              905                  1802             3
# Meghalaya           1971                   628            24
# Mizoram             1241                    40             5
# Nagaland            3037                  9180           615
# Odisha             24810                 29847          7521
# Puducherry           140                   201            48
# Punjab             23062                 24611          2977
# Rajasthan          43799                 55320          7769
# Sikkim              1237                  1428            71
# Tamil Nadu         11633                 23534          3314
# Telangana           5533                  5948          1724
# Tripura             8844                 21390          4976
# Uttar Pradesh      45694                133856         40615
# Uttarakhand         6207                 20319          2320
# West Bengal        29486                 51742          8075
#
#                    Assault against Women  Assault of Modesty  \
# State
# A & N Islands                        558                 135
# Andhra Pradesh                     92084               54684
# Arunachal Pradesh                   1584                  97
# Assam                              47115                2698
# Bihar                               9953                 800
# Chandigarh                           954                 281
# Chhattisgarh                       33310                4382
# D & D                               7619                 898
# Delhi Ut                           26039                6046
# Goa                                 1475                 475
# Gujarat                            18116                2925
# Haryana                            24347               11834
# Himachal Pradesh                    7574                1306
# Jammu & Kashmir                    22850                5179
# Jharkhand                          19771                1572
# Karnataka                          64492                3862
# Kerala                             69081                8873
# Lakshadweep                           23                  11
# Madhya Pradesh                    152000               21631
# Maharashtra                       107519               30693
# Manipur                             1131                  88
# Meghalaya                           1160                 108
# Mizoram                             1252                 162
# Nagaland                           27631                1487
# Odisha                             83473                7631
# Puducherry                           870                 343
# Punjab                             28644                2132
# Rajasthan                          67855                2365
# Sikkim                              2358                 118
# Tamil Nadu                         33885               12084
# Telangana                          23938                4836
# Tripura                            23744                 283
# Uttar Pradesh                      99650               46524
# Uttarakhand                         9160                2591
# West Bengal                        51014                5750
#
#                    Domestic Violece  Human trafficking
# State
# A & N Islands                   365                 10
# Andhra Pradesh               188511               2548
# Arunachal Pradesh               705                  7
# Assam                        135415                343
# Bihar                         55187                825
# Chandigarh                     1689                  7
# Chhattisgarh                  16381                103
# D & D                          8261                 41
# Delhi Ut                      27119                103
# Goa                             356                111
# Gujarat                       96480                493
# Haryana                       63266                519
# Himachal Pradesh               5420                 64
# Jammu & Kashmir                6274                 13
# Jharkhand                     22458                554
# Karnataka                     56202               2799
# Kerala                        84277                990
# Lakshadweep                      17                  0
# Madhya Pradesh                95521                396
# Maharashtra                  133357               2533
# Manipur                         443                 18
# Meghalaya                       379                 24
# Mizoram                         130                 14
# Nagaland                       8577                 66
# Odisha                        41222                270
# Puducherry                      178                 13
# Punjab                        53549                600
# Rajasthan                    201488                668
# Sikkim                         1629                613
# Tamil Nadu                    45393               4041
# Telangana                     44276                866
# Tripura                       42905                 43
# Uttar Pradesh                163062                333
# Uttarakhand                   47251                188
# West Bengal                  262235                940

# %% [markdown]
# ##Top 10 States/Union Territories With Highest number of reported crimes

# %%
pd.DataFrame(state_ut_crimes_df.sum(axis=1),columns=['Total Cases'] ).sort_values(by='Total Cases',ascending=False).head(10)
# Out:
#                 Total Cases
# State
# Uttar Pradesh        529734
# Madhya Pradesh       413157
# West Bengal          409242
# Andhra Pradesh       391123
# Rajasthan            379264
# Maharashtra          365632
# Assam                291980
# Kerala               202986
# Odisha               194774
# Bihar                189886

# %% [markdown]
# ###Top 10 States/Union Territories with Lowest number of reported crimes

# %%
pd.DataFrame(state_ut_crimes_df.sum(axis=1),columns=['Total Cases'] ).sort_values(by='Total Cases', ascending=True).head(10)
# Out:
#                    Total Cases
# State
# Lakshadweep                 72
# Puducherry                1793
# A & N Islands             1868
# Mizoram                   2844
# Goa                       4179
# Meghalaya                 4294
# Manipur                   4390
# Arunachal Pradesh         4822
# Chandigarh                5341
# Sikkim                    7454

# %% [markdown]
# ## Which crime was reported the most in which state

# %%
pd.DataFrame(state_ut_crimes_df.idxmax(),columns=['State'])
# Out:
#                                 State
# Rape                   Madhya Pradesh
# Kidnapping & Assault    Uttar Pradesh
# Dowry Deaths            Uttar Pradesh
# Assault against Women  Madhya Pradesh
# Assault of Modesty     Andhra Pradesh
# Domestic Violece          West Bengal
# Human trafficking          Tamil Nadu

# %% [markdown]
# Which crime was reported the least in which state

# %%
pd.DataFrame(state_ut_crimes_df.idxmin(),columns=['State'])
# Out:
#                              State
# Rape                   Lakshadweep
# Kidnapping & Assault   Lakshadweep
# Dowry Deaths           Lakshadweep
# Assault against Women  Lakshadweep
# Assault of Modesty     Lakshadweep
# Domestic Violece       Lakshadweep
# Human trafficking      Lakshadweep

# %% [markdown]
# ##Function to Analyse States

# %%
def analyze_state(state_name):
    try:
        fig = px.pie(state_ut_crimes_df, values=state_ut_crimes_df.loc[state_name],
                     names=state_ut_crimes_df.iloc[0,:].index, title='Total Crime Rate Distribution for {}'.format(state_name))
        fig.show()
    except KeyError:
        print('You Entered Wrong STATE/UT Name')

state_name=input('Enter Name of State/UT : ').title()
analyze_state(state_name)
# Out:
# Enter Name of State/UT : Uttar Pradesh
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="585d7b38-7225-410c-b066-e0d81448f2a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("585d7b38-7225-410c-b066-e0d81448f2a1")) {                    Plotly.newPlot(                        "585d7b38-7225-410c-b066-e0d81448f2a1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Rape","Kidnapping & Assault","Dowry Deaths","Assault against Women","Assault of Modesty","Domestic Violece","Human trafficking"],"legendgroup":"","name":"","showlegend":true,"values":[45694,133856,40615,99650,46524,163062,333],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outli ...

# %%
def get_state_year_data(df, state_name):
  try:
    state_data = df[df['State'] == state_name]
    year_wise_data = state_data.groupby('Year').sum()

    return year_wise_data
  except KeyError:
    print('You Entered Wrong STATE/UT Name')

state_name = input('Enter Name of State/UT : ').title()
year_wise_data = get_state_year_data(df, state_name)
year_wise_data.iloc[:,1:]
# Out:
# Enter Name of State/UT : Bihar
#       State  Rape  Kidnapping & Assault  Dowry Deaths  Assault against Women  \
# Year
# 2001  Bihar   888                   518           859                    562
# 2002  Bihar  1040                   744           927                    621
# 2003  Bihar   985                   674           909                    688
# 2004  Bihar  1390                   997          1029                    704
# 2005  Bihar  1147                   929          1014                    451
# 2006  Bihar  1232                  1084          1188                    530
# 2007  Bihar  1555                  1260          1172                    853
# 2008  Bihar  1302                  1789          1210                    999
# 2009  Bihar   929                  1986          1295                    726
# 2010  Bihar   795                  2569          1257                    534
# 2011  Bihar   934                  3050          1413                      0
# 2012  Bihar   927                  3789          1275                    118
# 2013  Bihar  1128                  4419          1182                    331
# 2014  Bihar  1127                  4735          2203                    572
# 2015  Bihar  1041                  5158          1154                    198
# 2016  Bihar  1008                  5496           987                    324
# 2017  Bihar   605                  6182          1081                    197
# 2018  Bihar   651                  7951          1107                    262
# 2019  Bihar   730                  9025          1120                    312
# 2020  Bihar   806                  6671          1046                    584
# 2021  Bihar   786                  8661          1000                    387
#
#       Assault of Modesty  Domestic Violece  Human trafficking
# Year
# 2001                  21              1558                 83
# 2002                   6              1577                 38
# 2003                  11              1880                 37
# 2004                  13              2679                 35
# 2005                  13              1574                 74
# 2006                  53              1689                 42
# 2007                  12              1635                 56
# 2008                  21              1992                 22
# 2009                  12              2532                 31
# 2010                  16              2271                  8
# 2011                  11              2607                 23
# 2012                  37              3686                 35
# 2013                  52              4533                 64
# 2014                 271              4672                 31
# 2015                  78              3792                 21
# 2016                 124              3794                 50
# 2017                   1              3776                 24
# 2018                  30              2539                 49
# 2019                  11              2397                 40
# 2020                   6              1935                 30
# 2021                   1              2069                 32
